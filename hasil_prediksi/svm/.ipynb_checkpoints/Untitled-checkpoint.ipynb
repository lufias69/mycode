# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
import re

# %%
sc
# Out:
# <SparkContext master=spark://192.168.88.254:7077 appName=PySparkShell>

# %%
def dfile (path):
    mypath = path
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    return onlyfiles

def reduksi_huruf(kata):
    nkata  = list()
    for i,k in enumerate(kata):
        if i>2:
            if kata[i]== kata[i-1] and kata[i] == kata[i-2]:
                continue
            else:
                nkata.append(k)
        else:
            nkata.append(k)
    return "".join(nkata)

def hapus_kata(kata, list_kata):
    katas = kata.split()
    for ix, kt in enumerate(katas):
        if kt in list_kata:
            katas[ix]=""
    ret = re.sub(' +', ' '," ".join(katas))
    # save_gdiganti()
    return ret.strip()

# %%
reduksi_huruf("sayaaaaaa lapaaaaaar beda ituuu")
hapus_kata("gigi raditya dika apalah",apalah)
# Out:
# 'apalah'

# %%
# import sys
#sys.path.append('D:\_onedrive\OneDrive\Tesis\implementasi\hasil_prediksi')
nama_file = dfile ('D:\_onedrive\OneDrive\Tesis\implementasi\hasil_prediksi')[:-1]
apalah = ["ayu","ting","at","rafathar","a", "aa", 'gigi',
          "raditya", "dika","award","rafatar","raffi", "nagita", 
          "raffinagita1717", "kakak", "kak","baim", "paula","acara",
          "radit",
          "via", "viavallen"]
komentar_list = list()
label_list = list()
ck_list = list()
for i in nama_file:
    d= pd.read_excel(i)
    k_ = d['komentar'].tolist()
    l_= d['prediksi'].tolist()
    n_k = list()
    n_l = list()
    tp_l = list()
    
    for k, l in zip (k_, l_):
        #print(".",end="")
        try:
            k = reduksi_huruf(k)
            k = hapus_kata(k,apalah)
        except:
            continue
        try:
            k_s = k.split()
            if len(k_s) >= 3 and l == "non spam":
                if k not in n_k:
                    n_k.append(k)
                    n_l.append(l)
                    tp_l.append(0)   
            elif len(k_s) >= 5 and l == "spam":
                if k not in n_k:
                    n_k.append(k)
                    n_l.append(l)
                    
                    for i in apalah:
                        cc = True
                        if i in k_s:
                            tp_l.append(1)
                            cc = False
                            break
                    if cc == True:
                        tp_l.append(0)
        except:
            continue
    #print("")
    komentar_list+=n_k
    label_list +=n_l
    ck_list += tp_l
dictt = {
    "label":label_list,
    "komentar":komentar_list,
    "kode salah": ck_list
}
df = pd.DataFrame.from_dict(dictt)
df.to_excel("seleksi/seleksi_10000_100000_2.xlsx")
df
# Out:
#           label                                           komentar  kode salah
# 0      non spam                        kucing pergi lemparin po it           0
# 1      non spam  fun dengar omong orang orang pernah ajar agama...           0
# 2      non spam               neilfebrina memang bisa lari darimuu           0
# 3      non spam                              cukur mat berewok nya           0
# 4      non spam                               punya istri sg galak           0
# 5      non spam                        i love jadi dangdut populer           0
# 6          spam  cek instagram yuk suntik putih ampuh original ...           0
# 7      non spam                                   contoh kalau tau           0
# 8      non spam                                   dekat ama nikita           0
# 9      non spam                                  cocok tuju vallen           0
# 10     non spam  duniamanji set dahsyat ke all about musil krn ...           0
# 11     non spam                       sujarwo gaspoull rempoull ow           0
# 12     non spam  aku nggoleki nadaeka ga anak yo pipit terimaka...           0
# 13         spam  sadar peluang paytren untung umur hidup aplika...           0
# 14     non spam                              kalah top sama vallen           0
# 15     non spam                               buset bang goa korek           0
# 16     non spam                    alhamdulillah k radai nya nikah           0
# 17         spam                 intan permatasarii efek samping ga           0
# 18     non spam                      mas hariyanto segmen sekarang           0
# 19     non spam                              ratna y auto download           0
# 20     non spam  ya follow ayu22m loh via2m liat aja real fans ...           0
# 21     non spam                            salam kota demak vallen           0
# 22     non spam                         vallen cantik banget allah           0
# 23         spam                    mirasih123 pokok hasil muas deh           0
# 24     non spam                    gendut lu bang cepat sadar diet           0
# 25         spam       vanderwick bagus gila hayati kecewa nonkezia           0
# 26     non spam  rafa anak pintar tdk sombong sayang moga srhat...           0
# 27     non spam  nonton dayuyuli juliaanggareni adiilesmana ris...           0
# 28     non spam                             seng bayar yo ra kroso           0
# 29     non spam                              iya ka juga nonton ko           0
# ...         ...                                                ...         ...
# 55436  non spam  awisuryadi mau madu duda biar sama japok itu p...           0
# 55437  non spam                                      eh masa nasib           0
# 55438  non spam                            caturharii idam youtube           0
# 55439      spam                          bagus pakai aja ada jelek           0
# 55440  non spam                                vallen are my idola           0
# 55441  non spam                                   met malam cantik           0
# 55442  non spam                         vallen bilsky16 harap satu           0
# 55443  non spam                           apa penting sehat vallen           0
# 55444  non spam  moga anak sholehah pintar guna nusa bangsa aga...           0
# 55445  non spam                    tanggung biar goyang kayak inul           0
# 55446  non spam  juri nya pandai nya lihat tampil aja bakat di ...           0
# 55447  non spam     fitriumanah28 kalo elu nya sejuk usaha si rafi           0
# 55448  non spam                          vallen kaya bocah sma itu           0
# 55449  non spam            salah deviafchaa elsamiftaw vanesawidya           0
# 55450  non spam                                    mecucu face vii           0
# 55451      spam    diet 5 kilogram minggu banget cek aja instagram           0
# 55452  non spam                            kasihan sama komen bang           0
# 55453  non spam  ayo bagai pahlawan basmi jahat tumpas lapar ha...           0
# 55454  non spam                                   muka japok pipit           0
# 55455  non spam  permatalaundrysolo sukoharjo gas ayo jemput ne...           0
# 55456      spam  cek instagram rumah fashion yukpusat fashion b...           0
# 55457  non spam                             kekeyuayu serah lu deh           0
# 55458  non spam                          allah ga jd mantu tante y           0
# 55459  non spam  indah dunia nyata wajah fans bahagia ada marah...           0
# 55460  non spam                      ga main moga g yang pd nonton           0
# 55461  non spam                               tidak di suci bang v           0
# 55462  non spam           tendang maut rafa ada ngerebut papa rafi           0
# 55463      spam                  nyokwikwik biar bisa hasil rezeki           0
# 55464  non spam                                ka ada lanjut part4           0
# 55465  non spam                                           i love u           0
#
# [55466 rows x 3 columns]
