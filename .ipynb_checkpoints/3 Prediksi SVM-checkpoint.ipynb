# %%
from model.svm import prediksi as svm

# %%
svm.prediksi2_single("")
# Out:
# 'non spam'

# %%
import pandas as pd
data = pd.read_excel('D:\_backup\_onedrive\OneDrive\Tesis\implementasi\Data/komentar_1_J3jt.xlsx', sheet_name='Sheet1')
data.head()
# Out:
#    Unnamed: 0                                           komentar
# 0           0  @homwsti iri bnget artisnya g d ajak acara ber...
# 1           3    Yang nulis email pasti nama depannya dr huruf S
# 2           4                           Salfok sama telinganya😹😹
# 3           5  @egapratiwwi youtubenya udh guankirim ke lu hahha
# 4           6  Abang radit mahh emang keren,,,,👏👏👏👍👍👍,,,terim...

# %%
x = [i for i in range(0, 100000+5000,5000)]
# x = [i for i in range(0, 10+5,5)]
x
# Out:
# [0,
#  5000,
#  10000,
#  15000,
#  20000,
#  25000,
#  30000,
#  35000,
#  40000,
#  45000,
#  50000,
#  55000,
#  60000,
#  65000,
#  70000,
#  75000,
#  80000,
#  85000,
#  90000,
#  95000,
#  100000]

# %%
for i,xk in enumerate(x):
#     print(x)
    if i+1 < len(x):
        print(x[i], x[i+1])
#         try:
        test = data['komentar'][x[i]:x[i+1]]
        df_prediksi = svm.prediksi_list(test)
        df_prediksi ["komentar_kotor"] = test.tolist()
#         svm.save_kata ()
        df_prediksi.to_excel("hasil_prediksi/uji/qq/"+str(x[i])+"_"+str(x[i+1])+".xlsx")
        print("=========================================================================================================", end=" ")
        print("")
# Out:
# 0 5000
# ....................................................................................................100 ...................................................................................................200 ...................................................................................................300 ...................................................................................................400 ...................................................................................................500 ...................................................................................................600 ...................................................................................................700 ...................................................................................................800 ...................................................................................................900 ...................................................................................................1000 ...................................................................................................1100 ...................................................................................................1200 ...................................................................................................1300 ...................................................................................................1400 ...................................................................................................1500 ...................................................................................................1600 ...................................................................................................1700 ...................................................................................................1800 ...................................................................................................1900 ...................................................................................................2000 ...................................................................................................2100 ...................................................................................................2200 ...................................................................................................2300 ...................................................................................................2400 ...................................................................................................2500 ...................................................................................................2600 ...................................................................................................2700 ...................................................................................................2800 ...................................................................................................2900 ...................................................................................................3000 ...................................................................................................3100 ...................................................................................................3200 ...................................................................................................3300 ...................................................................................................3400 ...................................................................................................3500 ...................................................................................................3600 ...................................................................................................3700 ...................................................................................................3800 ........................................................ ...
# <<Masuk Proses Prediksi>>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-54bbdd61be3b> in <module>
#       7         df_prediksi = svm.prediksi_list(test)
#       8         df_prediksi ["komentar_kotor"] = test.tolist()
# ----> 9         svm.save_kata ()
#      10         df_prediksi.to_excel("hasil_prediksi/uji/qq/"+str(x[i])+"_"+str(x[i+1])+".xlsx")
#      11         print("=========================================================================================================", end=" ")
#
# D:\_OneDrive\OneDrive - UGM 365\Penelitian\Koding\model\svm\prediksi.py in save_kata()
#      66     return pd.DataFrame.from_dict(dixt)
#      67 def save_kata ():
# ---> 68     pps.savek()
#      69
#      70
#
# D:\_OneDrive\OneDrive - UGM 365\Penelitian\Koding\Modul\Praproses_data.py in savek()
#      21 def savek ():
#      22     nkbi.save_gdiganti()
# ---> 23     ct.save_gdiganti()
#      24     stm.save_kta()
#      25 def saves():
#
# AttributeError: module 'Cek_typo.cek_typo' has no attribute 'save_gdiganti'

# %%
#BALANCE 50 50
    #
#IMBALANCE
