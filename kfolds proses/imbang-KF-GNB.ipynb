# %%
import joblib
import numpy as np
# from sklearn.naive_bayes import GaussianNB
# from sklearn.naive_bayes import MultinomialNB
# from sklearn.naive_bayes import ComplementNB
# import random
from Naive_Bayes import naive_bayes as nb

# %%
def batches(my_list, n):
    final = [my_list[i * n:(i + 1) * n] for i in range((len(my_list) + n - 1) // n )]
    return final

# %%
# mdl = joblib.load("imbang/gaussianNB.m")

# %%
md = joblib.load("imbang/imbang_data.dt")

# %%
md["model_tf"]
# Out:
# [{'model': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                   dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                   lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                   ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                   strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                   tokenizer=None, vocabulary=None),
#   'train': <17470x26092 sparse matrix of type '<class 'numpy.int64'>'
#   	with 211001 stored elements in Compressed Sparse Row format>,
#   'test': <1942x26092 sparse matrix of type '<class 'numpy.int64'>'
#   	with 21638 stored elements in Compressed Sparse Row format>,
#   'y_train': ['spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    ...],
#   'y_test': ['spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    ...]},
#  {'model': CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                   dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                   lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                   ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                   strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                   tokenizer=None, vocabulary=None),
#   'train': <17470x26392 sparse matrix of type '<class 'numpy.int64'>'
#   	with 211953 stored elements in Compressed Sparse Row format>,
#   'test': <1942x26392 sparse matrix of type '<class 'numpy.int64'>'
#   	with 21010 stored elements in Compressed Sparse Row format>,
#   'y_train': ['spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    ...],
#   'y_test': ['spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
# ...
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    ...],
#   'y_test': ['non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'non spam',
#    'spam',
#    'spam',
#    'non spam',
#    'non spam',
#    'non spam',
#    'spam',
#    'spam',
#    'spam',
#    'non spam',
#    ...]}]

# %%
# model_list=list()
# for i in range(10):
#     print(i, end=".")
#     X = md["model_tf_idf"][i]["train"]#.toarray()
#     Y = np.array(md["model_tf_idf"][i]["y_train"])
#     clf_pf = GaussianNB(var_smoothing = alp)
#     for batch in batches(np.arange(X.shape[0]), 1000):
#         clf_pf.partial_fit(X[batch].A, Y[batch], np.unique(Y))
#     model_list.append(clf_pf)

# %%
list_alpha = np.arange(0.01, 1+0.1, 0.1)
# list_alpha = np.array([0.000000000000000000000000000000001,0.00000000000000000001,0.0000000000000000001,0.00000000000000001,0.00000000000000001,0.0000000000000001,0.000000000000001,0.00000000000001,0.00000000000009])
print(len(list_alpha))
list_alpha
# Out:
# 11
# array([0.01, 0.11, 0.21, 0.31, 0.41, 0.51, 0.61, 0.71, 0.81, 0.91, 1.01])

# %%
from sklearn.metrics import accuracy_score
accc = list()
# list_alpha = np.arange(0.00001, 0.00009+0.00001, 0.00001)
for alp in list_alpha:
    
    lis_sc = list()
    for i in range(10): 
        X = md["model_tf_idf"][i]["train"]#.toarray()
        Y = np.array(md["model_tf_idf"][i]["y_train"])
        clf = nb.Gaussian(var_smoothing = alp)
        clf.train(X,Y)
        print(".", end="")
        y_pred = clf.predict_(md["model_tf_idf"][i]["test"])
        y_true = md["model_tf_idf"][i]["y_test"]
        lis_sc.append(accuracy_score(y_true, y_pred))
    print("")
    accc.append(sum(lis_sc)/len(lis_sc))
    print(alp,"<=>", sum(lis_sc)/len(lis_sc))
for i, j in zip(list_alpha, accc):
    print(i,"<=>", j)
# Out:
# ..........
# 0.001 <=> 0.6442923121025194
# ..........
# 0.011 <=> 0.861527493178464
# ..........
# 0.020999999999999998 <=> 0.863640948326202
# ..........
# 0.030999999999999996 <=> 0.8686376570014971
# ..........
# 0.040999999999999995 <=> 0.8719862082877681
# ..........
# 0.05099999999999999 <=> 0.8746133224330321
# ..........
# 0.06099999999999999 <=> 0.8754893456634143
# ..........
# 0.071 <=> 0.8751805981717222
# ..........
# 0.08099999999999999 <=> 0.8742019068448936
# ..........
# 0.09099999999999998 <=> 0.8713685540467369
# ..........
# 0.10099999999999998 <=> 0.8663716861137948
# ..........
# 0.11099999999999999 <=> 0.8574085064817861
# ..........
# 0.12099999999999998 <=> 0.841336012400862
# ..........
# 0.13099999999999998 <=> 0.8179997239534117
# ..........
# 0.141 <=> 0.785802870884517
# ..........
# 0.15099999999999997 <=> 0.7451574527270217
# ..........
# 0.16099999999999998 <=> 0.7062120568655972
# ..........
# 0.17099999999999999 <=> 0.6664426088526019
# ..........
# 0.18099999999999997 <=> 0.6288369944896853
# ..........
# 0.19099999999999998 <=> 0.5940644144096318
# ..........
# 0.20099999999999996 <=> 0.5590857549343327
# 0.001 <=> 0.6442923121025194
# 0.011 <=> 0.861527493178464
# 0.020999999999999998 <=> 0.863640948326202
# 0.030999999999999996 <=> 0.8686376570014971
# 0.040999999999999995 <=> 0.8719862082877681
# 0.05099999999999999 <=> 0.8746133224330321
# 0.06099999999999999 <=> 0.8754893456634143
# 0.071 <=> 0.8751805981717222
# 0.08099999999999999 <=> 0.8742019068448936
# 0.09099999999999998 <=> 0.8713685540467369
# 0.10099999999999998 <=> 0.8663716861137948
# 0.11099999999999999 <=> 0.8574085064817861
# 0.12099999999999998 <=> 0.841336012400862
# 0.13099999999999998 <=> 0.8179997239534117
# 0.141 <=> 0.785802870884517
# 0.15099999999999997 <=> 0.7451574527270217
# 0.16099999999999998 <=> 0.7062120568655972
# 0.17099999999999999 <=> 0.6664426088526019
# 0.18099999999999997 <=> 0.6288369944896853
# 0.19099999999999998 <=> 0.5940644144096318
# 0.20099999999999996 <=> 0.5590857549343327

# %%
for i, j in zip(list_alpha, accc):
    print(i,"<=>", j)
# Out:
# 0.01 <=> 0.8529245543440176
# 0.11 <=> 0.8584387972862496
# 0.21000000000000002 <=> 0.5324012337159056
# 0.31000000000000005 <=> 0.30012310616114746
# 0.41000000000000003 <=> 0.17051318122458514
# 0.51 <=> 0.11539092443755508
# 0.6100000000000001 <=> 0.10271900580759555
# 0.7100000000000001 <=> 0.09360065614150573
# 0.81 <=> 0.09169487296548356
# 0.91 <=> 0.0913858600443798
# 1.01 <=> 0.09148879357023794

# %%
from sklearn.metrics import accuracy_score
accc = list()
# list_alpha = np.arange(0.00001, 0.00009+0.00001, 0.00001)
for alp in list_alpha:
    
    lis_sc = list()
    for i in range(10): 
        X = md["model_tf"][i]["train"]#.toarray()
        Y = np.array(md["model_tf"][i]["y_train"])
        clf = nb.Gaussian(var_smoothing = alp)
        clf.train(X,Y)
        print(".", end="")
        y_pred = clf.predict_(md["model_tf"][i]["test"])
        y_true = md["model_tf"][i]["y_test"]
        lis_sc.append(accuracy_score(y_true, y_pred))
    print("")
    accc.append(sum(lis_sc)/len(lis_sc))
    print(alp,";", sum(lis_sc)/len(lis_sc))
for i, j in zip(list_alpha, accc):
    print(i,";", j)
# Out:
# ..........
# 0.01 ; 0.5894294329366047
# ..........
# 0.11 ; 0.7762727871149946
# ..........
# 0.21000000000000002 ; 0.7901827746928982
# ..........
# 0.31000000000000005 ; 0.7962617983373501
# ..........
# 0.41000000000000003 ; 0.8057926253092254
# ..........
# 0.51 ; 0.8172800386465223
# ..........
# 0.6100000000000001 ; 0.6709779481244759
# ..........
# 0.7100000000000001 ; 0.5193713569813243
# ..........
# 0.81 ; 0.4631683247157251
# ..........
# 0.91 ; 0.41598060241859275
# ..........
# 1.01 ; 0.37801395096987905
# 0.01 ; 0.5894294329366047
# 0.11 ; 0.7762727871149946
# 0.21000000000000002 ; 0.7901827746928982
# 0.31000000000000005 ; 0.7962617983373501
# 0.41000000000000003 ; 0.8057926253092254
# 0.51 ; 0.8172800386465223
# 0.6100000000000001 ; 0.6709779481244759
# 0.7100000000000001 ; 0.5193713569813243
# 0.81 ; 0.4631683247157251
# 0.91 ; 0.41598060241859275
# 1.01 ; 0.37801395096987905

# %%
from sklearn.metrics import accuracy_score
accc = list()
# list_alpha = np.arange(0.00001, 0.00009+0.00001, 0.00001)
for alp in list_alpha:
    
    lis_sc = list()
    for i in range(10): 
        X = md["model_bin"][i]["train"]#.toarray()
        Y = np.array(md["model_bin"][i]["y_train"])
        clf = nb.Gaussian(var_smoothing = alp)
        clf.train(X,Y)
        print(".", end="")
        y_pred = clf.predict_(md["model_bin"][i]["test"])
        y_true = md["model_bin"][i]["y_test"]
        lis_sc.append(accuracy_score(y_true, y_pred))
    print("")
    accc.append(sum(lis_sc)/len(lis_sc))
    print(alp,"<=>", sum(lis_sc)/len(lis_sc))
for i, j in zip(list_alpha, accc):
    print(i,";", j)
# Out:
# ..........
# 0.001 <=> 0.7761184133691486
# ..........
# 0.011 <=> 0.8003306188752163
# ..........
# 0.020999999999999998 <=> 0.8016700287725482
# ..........
# 0.030999999999999996 <=> 0.804709036278892
# ..........
# 0.040999999999999995 <=> 0.8060479684032827
# ..........
# 0.05099999999999999 <=> 0.8059959973244715
# ..........
# 0.06099999999999999 <=> 0.7988872137343794
# ..........
# 0.071 <=> 0.7850297280941105
# ..........
# 0.08099999999999999 <=> 0.7576245660229118
# ..........
# 0.09099999999999998 <=> 0.7209449287056601
# ..........
# 0.10099999999999998 <=> 0.6786511408156116
# ..........
# 0.11099999999999999 <=> 0.6388841347532038
# ..........
# 0.12099999999999998 <=> 0.6024113200335502
# ..........
# 0.13099999999999998 <=> 0.5653220189622771
# ..........
# 0.141 <=> 0.5338466561202713
# ..........
# 0.15099999999999997 <=> 0.5077286674381816
# ..........
# 0.16099999999999998 <=> 0.48269219743701364
# ..........
# 0.17099999999999999 <=> 0.4594589486871861
# ..........
# 0.18099999999999997 <=> 0.4410169131621138
# ..........
# 0.19099999999999998 <=> 0.42365692717678655
# ..........
# 0.20099999999999996 <=> 0.40686405767250255
# ..........
# 0.21099999999999997 <=> 0.39233662819709725
# ..........
# 0.22099999999999997 <=> 0.3807459097327656
# ..........
# 0.23099999999999996 <=> 0.3695148481212906
# ..........
# 0.24099999999999996 <=> 0.3596232494930299
# ..........
# 0.25099999999999995 <=> 0.3504023909881407
# ..........
# 0.26099999999999995 <=> 0.34231390743945556
# ..........
# 0.27099999999999996 <=> 0.3350501130729294
# ..........
# 0.28099999999999997 <=> 0.329074713070806
# ..........
# 0.291 <=> 0.3218624650960324
# ..........
# 0.30099999999999993 <=> 0.314856243430622
# 0.001 ; 0.7761184133691486
# 0.011 ; 0.8003306188752163
# 0.020999999999999998 ; 0.8016700287725482
# 0.030999999999999996 ; 0.804709036278892
# 0.040999999999999995 ; 0.8060479684032827
# 0.05099999999999999 ; 0.8059959973244715
# 0.06099999999999999 ; 0.7988872137343794
# 0.071 ; 0.7850297280941105
# 0.08099999999999999 ; 0.7576245660229118
# 0.09099999999999998 ; 0.7209449287056601
# 0.10099999999999998 ; 0.6786511408156116
# 0.11099999999999999 ; 0.6388841347532038
# 0.12099999999999998 ; 0.6024113200335502
# 0.13099999999999998 ; 0.5653220189622771
# 0.141 ; 0.5338466561202713
# 0.15099999999999997 ; 0.5077286674381816
# 0.16099999999999998 ; 0.48269219743701364
# 0.17099999999999999 ; 0.4594589486871861
# 0.18099999999999997 ; 0.4410169131621138
# 0.19099999999999998 ; 0.42365692717678655
# 0.20099999999999996 ; 0.40686405767250255
# 0.21099999999999997 ; 0.39233662819709725
# 0.22099999999999997 ; 0.3807459097327656
# 0.23099999999999996 ; 0.3695148481212906
# 0.24099999999999996 ; 0.3596232494930299
# 0.25099999999999995 ; 0.3504023909881407
# 0.26099999999999995 ; 0.34231390743945556
# 0.27099999999999996 ; 0.3350501130729294
# 0.28099999999999997 ; 0.329074713070806
# 0.291 ; 0.3218624650960324
# 0.30099999999999993 ; 0.314856243430622

# %%
accc = list()
# list_alpha = np.arange(0.00001, 0.00009+0.00001, 0.00001)
for alp in list_alpha:
    lis_sc = list()
    for i in range(10): 
        X = md["model_tf_idf"][i]["train"]#.toarray()
        Y = np.array(md["model_tf_idf"][i]["y_train"])
        clf_pf = GaussianNB(var_smoothing = alp)
        for batch in batches(np.arange(X.shape[0]), 1000):
            clf_pf.partial_fit(X[batch].A, Y[batch], np.unique(Y))
#         print(i, end=".")
#         clf_pf = model_list[i]
#         clf = clf_pf.set_params(var_smoothing = alp)
        lisskor_batch = list()
        for batch in batches(np.arange(md["model_tf_idf"][i]["test"].shape[0]), 10):
            sc = clf_pf.score(md["model_tf_idf"][i]["test"][batch].A, np.array(md["model_tf_idf"][i]["y_test"])[batch])
            lisskor_batch.append(sc)
        lis_sc.append(sum(lisskor_batch)/len(lisskor_batch))
    print("")   
    accc.append(sum(lis_sc)/len(lis_sc))
    print(alp, sum(lis_sc)/len(lis_sc))
print("")
for i, j in zip(list_alpha, accc):
    print(i, j)
print("alpha :",list_alpha[accc.index(max(accc))])
# Out:
# 1e-05 0.8203425852498025
#
# 2e-05 0.825073486650807
#
# 3e-05 0.8290822098863344
#
# 4e-05 0.832216759185832
#
# 5e-05 0.8344781919111824
#
# 6e-05 0.8364803066349467
#
# 7e-05 0.8380737509912777
#
# 8e-05 0.8399754163362418
#
# 1e-05 0.8203425852498025
# 2e-05 0.825073486650807
# 3e-05 0.8290822098863344
# 4e-05 0.832216759185832
# 5e-05 0.8344781919111824
# 6e-05 0.8364803066349467
# 7e-05 0.8380737509912777
# 8e-05 0.8399754163362418
# alpha : 8e-05

# %%
1e-05 0.8203425852498025
2e-05 0.825073486650807
3e-05 0.8290822098863344
4e-05 0.832216759185832
5e-05 0.8344781919111824
6e-05 0.8364803066349467
7e-05 0.8380737509912777
8e-05 0.8399754163362418
9e-05 0.8403869944488511
0.0009 0.8451683848797259
0.009 0.8490726936293959
0.09 0.8562709489822904
0.1 0.8509265133491951
0.2 0.7649444885011899
0.3 0.6751104943166799
0.4 0.6052320909331217
0.5 0.5619220195611947
0.6 0.5379275707110758
0.7 0.52138197197991
0.8 0.5125942373777423
0.9 0.5072495374041763

# %%
accc = list()
# list_alpha = np.arange(0.00001, 0.00009+0.00001, 0.00001)
for alp in list_alpha:
    lis_sc = list()
    for i in range(10):
        
        X = md["model_tf"][i]["train"]#.toarray()
        Y = np.array(md["model_tf"][i]["y_train"])
        clf_pf = GaussianNB(var_smoothing = alp)
        for batch in batches(np.arange(X.shape[0]), 1000):
            clf_pf.partial_fit(X[batch].A, Y[batch], np.unique(Y))
#         print(i, end=".")
#         clf_pf = model_list[i]
#         clf = clf_pf.set_params(var_smoothing = alp)
        lisskor_batch = list()
        for batch in batches(np.arange(md["model_tf"][i]["test"].shape[0]), 10):
            sc = clf_pf.score(md["model_tf"][i]["test"][batch].A, np.array(md["model_tf_idf"][i]["y_test"])[batch])
            lisskor_batch.append(sc)
        lis_sc.append(sum(lisskor_batch)/len(lisskor_batch))
    print("")   
    accc.append(sum(lis_sc)/len(lis_sc))
    print(alp, sum(lis_sc)/len(lis_sc))
print("")
for i, j in zip(list_alpha, accc):
    print(i, j)
print("alpha :",list_alpha[accc.index(max(accc))])
# Out:
# 1e-33 0.7917697594501724
#
# 1e-20 0.7917697594501724
#
# 1e-19 0.7917697594501724
#
# 1e-17 0.7917697594501724
#
# 1e-17 0.7917697594501724
#
# 1e-16 0.7917697594501724
#
# 1e-15 0.7917697594501724
#
# 1e-14 0.7917697594501724
#
# 9e-14 0.7917697594501724
#
# 1e-33 0.7917697594501724
# 1e-20 0.7917697594501724
# 1e-19 0.7917697594501724
# 1e-17 0.7917697594501724
# 1e-17 0.7917697594501724
# 1e-16 0.7917697594501724
# 1e-15 0.7917697594501724
# 1e-14 0.7917697594501724
# 9e-14 0.7917697594501724
# alpha : 1e-33

# %%
1e-33 0.7917697594501724
1e-20 0.7917697594501724
1e-19 0.7917697594501724
1e-17 0.7917697594501724
1e-17 0.7917697594501724
1e-16 0.7917697594501724
1e-15 0.7917697594501724
1e-14 0.7917697594501724
9e-14 0.7917697594501724

1e-18 0.7917697594501724
1e-17 0.7917697594501724
1e-15 0.7917697594501724
1e-15 0.7917697594501724
1e-14 0.7917697594501724
1e-13 0.7917697594501724
1e-12 0.7917697594501724
9e-12 0.7917697594501724

1e-15 0.7917697594501724
1e-14 0.7917697594501724
1e-13 0.7917697594501724
1e-12 0.7917697594501724
1e-11 0.7917697594501724
1e-10 0.7917697594501724
1e-09 0.7917697594501724
9e-09 0.7917179487179493
1e-12 0.7917697594501724
1e-11 0.7917697594501724
1e-10 0.7917697594501724
1e-09 0.7917697594501724
1e-08 0.7917182130584198
1e-07 0.7934134284959034
1e-06 0.7885292096219937
9e-06 0.6669928628072956

1e-05 0.653786941580756

2e-05 0.5641213322759715

3e-05 0.5242001057361882

4e-05 0.5091966693100715

5e-05 0.5031334919376158

6e-05 0.501130055511499

9e-05 0.5001538461538463
0.0009 0.5000000000000001
0.009 0.5000000000000001
0.09 0.5000000000000001
0.1 0.5000000000000001
0.2 0.5000000000000001
0.3 0.5000000000000001
0.4 0.5000000000000001
0.5 0.5000000000000001
0.6 0.5000000000000001
0.7 0.5000000000000001
0.8 0.5000000000000001
0.9 0.5000000000000001
1.0 0.5000000000000001
alpha : 9e-05

# %%
accc = list()
# list_alpha = np.arange(0.00001, 0.00009+0.00001, 0.00001)
for alp in list_alpha:
    lis_sc = list()
    for i in range(10):
        
        X = md["model_bin"][i]["train"]#.toarray()
        Y = np.array(md["model_bin"][i]["y_train"])
        clf_pf = GaussianNB(var_smoothing = alp)
        for batch in batches(np.arange(X.shape[0]), 1000):
            clf_pf.partial_fit(X[batch].A, Y[batch], np.unique(Y))
#         print(i, end=".")
#         clf_pf = model_list[i]
#         clf = clf_pf.set_params(var_smoothing = alp)
        lisskor_batch = list()
        for batch in batches(np.arange(md["model_tf_idf"][i]["test"].shape[0]), 10):
            sc = clf_pf.score(md["model_tf_idf"][i]["test"][batch].A, np.array(md["model_tf_idf"][i]["y_test"])[batch])
            lisskor_batch.append(sc)
        lis_sc.append(sum(lisskor_batch)/len(lisskor_batch))
    print("")   
    accc.append(sum(lis_sc)/len(lis_sc))
    print(alp, sum(lis_sc)/len(lis_sc))
print("")
for i, j in zip(list_alpha, accc):
    print(i, j)
print("alpha :",list_alpha[accc.index(max(accc))])
# Out:
# 1e-18 0.791873116574148
#
# 1e-17 0.791873116574148
#
# 1e-15 0.791873116574148
#
# 1e-15 0.791873116574148
#
# 1e-14 0.791873116574148
#
# 1e-13 0.791873116574148
#
# 1e-12 0.791873116574148
#
# 9e-12 0.791873116574148
#
# 1e-18 0.791873116574148
# 1e-17 0.791873116574148
# 1e-15 0.791873116574148
# 1e-15 0.791873116574148
# 1e-14 0.791873116574148
# 1e-13 0.791873116574148
# 1e-12 0.791873116574148
# 9e-12 0.791873116574148
# alpha : 1e-18

# %%
model_bin
"""
1e-18 0.791873116574148
1e-17 0.791873116574148
1e-15 0.791873116574148
1e-14 0.791873116574148
1e-13 0.791873116574148
1e-12 0.791873116574148
1e-11 0.791873116574148
1e-10 0.791873116574148
1e-09 0.791873116574148
9e-09 0.7919754163362417
1e-12 0.791873116574148
1e-11 0.791873116574148
1e-10 0.791873116574148
1e-09 0.791873116574148
1e-08 0.7919748876553007
1e-07 0.7936185567010317
1e-06 0.7938757599788534
9e-06 0.7914607454401275
9e-05 0.7017388316151202
0.0009 0.5014922019561195
0.009 0.5000000000000001
0.09 0.5000000000000001
0.1 0.5000000000000001
0.2 0.5000000000000001
0.3 0.5000000000000001
0.4 0.5000000000000001
0.5 0.5000000000000001
0.6 0.5000000000000001
0.7 0.5000000000000001
0.8 0.5000000000000001
0.9 0.5000000000000001
1.0 0.5000000000000001
alpha : 9e-05"""
# Out:
# '9e-05 0.7017388316151202\n0.0009 0.5014922019561195\n0.009 0.5000000000000001\n0.09 0.5000000000000001\n0.1 0.5000000000000001\n0.2 0.5000000000000001\n0.3 0.5000000000000001\n0.4 0.5000000000000001\n0.5 0.5000000000000001\n0.6 0.5000000000000001\n0.7 0.5000000000000001\n0.8 0.5000000000000001\n0.9 0.5000000000000001\n1.0 0.5000000000000001\nalpha : 9e-05'

# %%
# model_list=list()
# for i in range(10):
#     print(i, end=".")
#     X = md["model_tf"][i]["train"]#.toarray()
#     Y = np.array(md["model_tf"][i]["y_train"])
#     clf_pf = GaussianNB(var_smoothing = alp)
#     for batch in batches(np.arange(X.shape[0]), 1000):
#         clf_pf.partial_fit(X[batch].A, Y[batch], np.unique(Y))
#     model_list.append(clf_pf)

# %%
accc = list()
# list_alpha = np.arange(0.00001, 0.00009+0.00001, 0.00001)
for alp in list_alpha:
    lis_sc = list()
    for i in range(10):
        print(i, end=".")
        clf_pf = model_list[i]
        clf_pf.set_params(var_smoothing = alp)
        lisskor_batch = list()
        for batch in batches(np.arange(md["model_tf"][i]["test"].shape[0]), 10):
            sc = clf_pf.score(md["model_tf"][i]["test"][batch].A, np.array(md["model_tf"][i]["y_test"])[batch])
            lisskor_batch.append(sc)
        lis_sc.append(sum(lisskor_batch)/len(lisskor_batch))
    print("")   
    accc.append(sum(lis_sc)/len(lis_sc))
    print(alp, sum(lis_sc)/len(lis_sc))
print("")
for i, j in zip(list_alpha, accc):
    print(i, j)
print("alpha :",list_alpha[accc.index(max(accc))])

# %%
model_list=list()
for i in range(10):
    print(i, end=".")
    X = md["model_bin"][i]["train"]#.toarray()
    Y = np.array(md["model_bin"][i]["y_train"])
    clf_pf = GaussianNB(var_smoothing = alp)
    for batch in batches(np.arange(X.shape[0]), 1000):
        clf_pf.partial_fit(X[batch].A, Y[batch], np.unique(Y))
    model_list.append(clf_pf)

# %%
accc = list()
# list_alpha = np.arange(0.00001, 0.00009+0.00001, 0.00001)
for alp in list_alpha:
    lis_sc = list()
    for i in range(10):
        print(i, end=".")
        clf_pf = model_list[i]
        clf_pf.set_params(var_smoothing = alp)
        lisskor_batch = list()
        for batch in batches(np.arange(md["model_bin"][i]["test"].shape[0]), 10):
            sc = clf_pf.score(md["model_bin"][i]["test"][batch].A, np.array(md["model_bin"][i]["y_test"])[batch])
            lisskor_batch.append(sc)
        lis_sc.append(sum(lisskor_batch)/len(lisskor_batch))
    print("")   
    accc.append(sum(lis_sc)/len(lis_sc))
    print(alp, sum(lis_sc)/len(lis_sc))
print("")
for i, j in zip(list_alpha, accc):
    print(i, j)
print("alpha :",list_alpha[accc.index(max(accc))])
