# %%
import joblib
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import ComplementNB
import random

# %%
def batches(my_list, n):
    final = [my_list[i * n:(i + 1) * n] for i in range((len(my_list) + n - 1) // n )]
    return final

# %%
md = joblib.load("data.dt")

# %%
list_alpha = np.arange(0.01, 3+0.1, 0.1)
list_alpha
# Out:
# array([0.01, 0.11, 0.21, 0.31, 0.41, 0.51, 0.61, 0.71, 0.81, 0.91, 1.01,
#        1.11, 1.21, 1.31, 1.41, 1.51, 1.61, 1.71, 1.81, 1.91, 2.01, 2.11,
#        2.21, 2.31, 2.41, 2.51, 2.61, 2.71, 2.81, 2.91, 3.01])

# %%
accc = list()

for alp in list_alpha:
    lis_sc = list()
    for i in range(10):
        X = md["model_tf_idf"][i]["train"]#.toarray()
        Y = np.array(md["model_tf_idf"][i]["y_train"])
        clf_pf = MultinomialNB(alpha = alp)
        for batch in batches(np.arange(X.shape[0]), 1000):
            clf_pf.partial_fit(X[batch].A, Y[batch], np.unique(Y))
#             clf_pf.fit(X, Y)
        lisskor_batch = list()
        for batch in batches(np.arange(md["model_tf_idf"][i]["test"].shape[0]), 10):
            sc = clf_pf.score(md["model_tf_idf"][i]["test"][batch].A, np.array(md["model_tf_idf"][i]["y_test"])[batch])
            lisskor_batch.append(sc)
        lis_sc.append(sum(lisskor_batch)/len(lisskor_batch))
        
    accc.append(sum(lis_sc)/len(lis_sc))
    print(alp, sum(lis_sc)/len(lis_sc))
print("")
for i, j in zip(list_alpha, accc):
    print(i, j)
print("alpha :",list_alpha[accc.index(max(accc))])
# Out:
# 0.01 0.9547258134022802
# 0.11 0.9594656324068053
# 0.21000000000000002 0.9603856927386305
# 0.31000000000000005 0.9606722689075596
# 0.41000000000000003 0.9606571859513002
# 0.51 0.9601960784313691
# 0.6100000000000001 0.9594505494505459
# 0.7100000000000001 0.9588924800689471
# 0.81 0.9579573367808625
# 0.91 0.9569015298427027
# 1.01 0.9559663865546181
# 1.11 0.9550915750915714
# 1.2100000000000002 0.9541262658909678
# 1.31 0.9531307907778457
# 1.4100000000000001 0.9521503986209829
# 1.51 0.9511448682036878
# 1.61 0.9503002226531599
# 1.7100000000000002 0.9493650793650753
# 1.81 0.9484902679020287
# 1.9100000000000001 0.9478266178266139
# 2.01 0.9468663362780971
# 2.11 0.9461423543776446
# 2.21 0.9452977088271167
# 2.31 0.9443022337139944
# 2.41 0.9435933347698013
# 2.51 0.9426732744379762
# 2.61 0.9420397902750803
# 2.71 0.9413610572434061
# 2.81 0.9406521582992131
# 2.91 0.9399734252675389
# 3.01 0.9391136967607515
#
# 0.01 0.9547258134022802
# 0.11 0.9594656324068053
# 0.21000000000000002 0.9603856927386305
# 0.31000000000000005 0.9606722689075596
# 0.41000000000000003 0.9606571859513002
# 0.51 0.9601960784313691
# 0.6100000000000001 0.9594505494505459
# 0.7100000000000001 0.9588924800689471
# 0.81 0.9579573367808625
# 0.91 0.9569015298427027
# 1.01 0.9559663865546181
# 1.11 0.9550915750915714
# 1.2100000000000002 0.9541262658909678
# 1.31 0.9531307907778457
# 1.4100000000000001 0.9521503986209829
# 1.51 0.9511448682036878
# 1.61 0.9503002226531599
# 1.7100000000000002 0.9493650793650753
# 1.81 0.9484902679020287
# 1.9100000000000001 0.9478266178266139
# 2.01 0.9468663362780971
# 2.11 0.9461423543776446
# 2.21 0.9452977088271167
# 2.31 0.9443022337139944
# 2.41 0.9435933347698013
# 2.51 0.9426732744379762
# 2.61 0.9420397902750803
# 2.71 0.9413610572434061
# 2.81 0.9406521582992131
# 2.91 0.9399734252675389
# 3.01 0.9391136967607515
# alpha : 0.31000000000000005

# %%
accc = list()
# list_alpha = np.arange(0.01, 5+0.1, 0.1)
for alp in list_alpha:
    lis_sc = list()
    for i in range(10):
        X = md["model_tf"][i]["train"]#.toarray()
        Y = np.array(md["model_tf"][i]["y_train"])
        clf_pf = MultinomialNB(alpha = alp)
        for batch in batches(np.arange(X.shape[0]), 1000):
            clf_pf.partial_fit(X[batch].A, Y[batch], np.unique(Y))
#             clf_pf.fit(X, Y)
        lisskor_batch = list()
        for batch in batches(np.arange(md["model_tf_idf"][i]["test"].shape[0]), 10):
            sc = clf_pf.score(md["model_tf_idf"][i]["test"][batch].A, np.array(md["model_tf_idf"][i]["y_test"])[batch])
            lisskor_batch.append(sc)
        lis_sc.append(sum(lisskor_batch)/len(lisskor_batch)) 
        
    accc.append(sum(lis_sc)/len(lis_sc))
    print(alp, sum(lis_sc)/len(lis_sc))
print("")
for i, j in zip(list_alpha, accc):
    print(i, j)
print("alpha :",list_alpha[accc.index(max(accc))])
# Out:
# 0.01 0.9519656324068053
# 0.11 0.9569316957552216
# 0.21000000000000002 0.9581081663434569
# 0.31000000000000005 0.9588924800689472
# 0.41000000000000003 0.95934496875673
# 0.51 0.9597974574445128
# 0.6100000000000001 0.9603404438698522
# 0.7100000000000001 0.9604158586511493
# 0.81 0.9605128205128171
# 0.91 0.9605580693815954
# 1.01 0.9606184012066331
# 1.11 0.9606184012066331
# 1.2100000000000002 0.9607993966817462
# 1.31 0.9609049773755622
# 1.4100000000000001 0.9608898944193027
# 1.51 0.9606270200387812
# 1.61 0.9605817711700031
# 1.7100000000000002 0.9605516052574842
# 1.81 0.9604460245636682
# 1.9100000000000001 0.9603404438698522
# 2.01 0.9602348631760362
# 2.11 0.960084033613442
# 2.21 0.9599784529196258
# 2.31 0.959978452919626
# 2.41 0.9599332040508477
# 2.51 0.9597672915319938
# 2.61 0.9596767937944373
# 2.71 0.9594807153630647
# 2.81 0.9593902176255084
# 2.91 0.959314802844211
# 3.01 0.9590885585003195
#
# 0.01 0.9519656324068053
# 0.11 0.9569316957552216
# 0.21000000000000002 0.9581081663434569
# 0.31000000000000005 0.9588924800689472
# 0.41000000000000003 0.95934496875673
# 0.51 0.9597974574445128
# 0.6100000000000001 0.9603404438698522
# 0.7100000000000001 0.9604158586511493
# 0.81 0.9605128205128171
# 0.91 0.9605580693815954
# 1.01 0.9606184012066331
# 1.11 0.9606184012066331
# 1.2100000000000002 0.9607993966817462
# 1.31 0.9609049773755622
# 1.4100000000000001 0.9608898944193027
# 1.51 0.9606270200387812
# 1.61 0.9605817711700031
# 1.7100000000000002 0.9605516052574842
# 1.81 0.9604460245636682
# 1.9100000000000001 0.9603404438698522
# 2.01 0.9602348631760362
# 2.11 0.960084033613442
# 2.21 0.9599784529196258
# 2.31 0.959978452919626
# 2.41 0.9599332040508477
# 2.51 0.9597672915319938
# 2.61 0.9596767937944373
# 2.71 0.9594807153630647
# 2.81 0.9593902176255084
# 2.91 0.959314802844211
# 3.01 0.9590885585003195
# alpha : 1.31

# %%
accc = list()
# list_alpha = np.arange(0.01, 5+0.1, 0.1)
for alp in list_alpha:
    lis_sc = list()
    for i in range(10):
        X = md["model_bin"][i]["train"]#.toarray()
        Y = np.array(md["model_bin"][i]["y_train"])
        clf_pf = MultinomialNB(alpha = alp)
        for batch in batches(np.arange(X.shape[0]), 1000):
            clf_pf.partial_fit(X[batch].A, Y[batch], np.unique(Y))
#             clf_pf.fit(X, Y)
        lisskor_batch = list()
        for batch in batches(np.arange(md["model_tf_idf"][i]["test"].shape[0]), 10):
            sc = clf_pf.score(md["model_tf_idf"][i]["test"][batch].A, np.array(md["model_tf_idf"][i]["y_test"])[batch])
            lisskor_batch.append(sc)
        lis_sc.append(sum(lisskor_batch)/len(lisskor_batch))
        
    accc.append(sum(lis_sc)/len(lis_sc))
    print(alp, sum(lis_sc)/len(lis_sc))
print("")
for i, j in zip(list_alpha, accc):
    print(i, j)
print("alpha :",list_alpha[accc.index(max(accc))])
# Out:
# 0.01 0.9522220426632154
# 0.11 0.9568864468864433
# 0.21000000000000002 0.9583796595561266
# 0.31000000000000005 0.9593600517129893
# 0.41000000000000003 0.9597069597069561
# 0.51 0.9601745313509985
# 0.6100000000000001 0.960506356388706
# 0.7100000000000001 0.9606270200387813
# 0.81 0.9606421029950407
# 0.91 0.9606421029950407
# 1.01 0.9609502262443405
# 1.11 0.9610105580693782
# 1.2100000000000002 0.9610342598577859
# 1.31 0.9609437621202293
# 1.4100000000000001 0.9608532643826727
# 1.51 0.9607326007325974
# 1.61 0.9607024348200784
# 1.7100000000000002 0.9604460245636682
# 1.81 0.9603706097823711
# 1.9100000000000001 0.9603555268261117
# 2.01 0.9601594483947391
# 2.11 0.9601594483947391
# 2.21 0.9601141995259608
# 2.31 0.9598879551820694
# 2.41 0.9597069597069561
# 2.51 0.9596013790131401
# 2.61 0.9595259642318432
# 2.71 0.9592544710191733
# 2.81 0.9592092221503948
# 2.91 0.959103641456579
# 3.01 0.9588472312001686
#
# 0.01 0.9522220426632154
# 0.11 0.9568864468864433
# 0.21000000000000002 0.9583796595561266
# 0.31000000000000005 0.9593600517129893
# 0.41000000000000003 0.9597069597069561
# 0.51 0.9601745313509985
# 0.6100000000000001 0.960506356388706
# 0.7100000000000001 0.9606270200387813
# 0.81 0.9606421029950407
# 0.91 0.9606421029950407
# 1.01 0.9609502262443405
# 1.11 0.9610105580693782
# 1.2100000000000002 0.9610342598577859
# 1.31 0.9609437621202293
# 1.4100000000000001 0.9608532643826727
# 1.51 0.9607326007325974
# 1.61 0.9607024348200784
# 1.7100000000000002 0.9604460245636682
# 1.81 0.9603706097823711
# 1.9100000000000001 0.9603555268261117
# 2.01 0.9601594483947391
# 2.11 0.9601594483947391
# 2.21 0.9601141995259608
# 2.31 0.9598879551820694
# 2.41 0.9597069597069561
# 2.51 0.9596013790131401
# 2.61 0.9595259642318432
# 2.71 0.9592544710191733
# 2.81 0.9592092221503948
# 2.91 0.959103641456579
# 3.01 0.9588472312001686
# alpha : 1.2100000000000002
