# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.metrics import classification_report
from plot_cm import plot

# %%
root = "../../"

# %%
data=pd.read_excel(root+r"data\data_uji\data_ujiX1234.xlsx")
komentar2 = data.komentar_bersih.tolist()
komentar = data.komentar.tolist()
y_true  = data.label.tolist()
data.head()
# Out:
#    Column1  Unnamed: 0  Unnamed: 1     label  \
# 0    741.0       741.0           1  non spam
# 1    777.0       777.0           2  non spam
# 2    790.0       790.0           3  non spam
# 3    855.0       855.0           4  non spam
# 4    869.0       869.0           5  non spam
#
#                                             komentar  \
# 0  @nurtunggali hanya di @rissa_skincare y say.. ...
# 1  @legitenak hahahaha balajaer mah gitu kadang b...
# 2  @bundanya.anak.anak  lu lah, muka kayak mak la...
# 3  @lazarus_smith1717 anyway parameter kita beda,...
# 4  @awukyu iyalah akun bodong yg doyan nyinyir ka...
#
#                                      komentar_bersih
# 0  nurtunggali risa skin care y nan awas hati 2 o...
# 1  legitenak nan balajaer mah gitu kadang buta sm...
# 2  badan anak anak lu lah muka kayak mak lampir s...
# 3  lazarus smith 1717 anyway parameter beda gue o...
# 4  awukyu iya akun bodong doyan nyinyir kaya lu o...

# %%
#load model
path = root+r"Pemodelan/data1/"

# %%
pembobotan_imbang_freq = joblib.load(path+"imbang/"+"pembobotan_tf.w")
pembobotan_imbang_bin = joblib.load(path+"imbang/"+"pembobotan_bin.w")

# %% [markdown]
# # CNB

# %%
cnb_tfidf = joblib.load(path+"imbang/"+"cnb_tfidf.model")
cnb_tf = joblib.load(path+"imbang/"+"cnb_tf.model")
cnb_bin = joblib.load(path+"imbang/"+"cnb_bin.model")

# %% [markdown]
# ### 1. TFIDF CNB

# %%
cnb_tfidf.set_params(alpha = 1)
# print(cnb_tfidf)
y_pred = cnb_tfidf.predict(pembobotan_imbang_freq.transform(komentar))
# target_names = ['spam','non spam']
# target_names = list(set(y_true))
# print(target_names)
# print(classification_report(y_true, y_pred, target_names=target_names))
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     non spam       0.91      0.88      0.89       726
#         spam       0.88      0.91      0.90       725
#
#     accuracy                           0.89      1451
#    macro avg       0.89      0.89      0.89      1451
# weighted avg       0.89      0.89      0.89      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %%
print("")
y_pred = cnb_tfidf.predict(pembobotan_imbang_freq.transform(komentar2))
# target_names = list(set(y_true))
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     non spam       1.00      0.89      0.94       726
#         spam       0.90      1.00      0.95       725
#
#     accuracy                           0.94      1451
#    macro avg       0.95      0.94      0.94      1451
# weighted avg       0.95      0.94      0.94      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %% [markdown]
# ### 2. TF CNB

# %%
y_pred = cnb_tf.predict(pembobotan_imbang_freq.transform(komentar))
target_names = list(set(y_true))
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     non spam       0.90      0.92      0.91       726
#         spam       0.92      0.90      0.91       725
#
#     accuracy                           0.91      1451
#    macro avg       0.91      0.91      0.91      1451
# weighted avg       0.91      0.91      0.91      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %%
y_pred = cnb_tf.predict(pembobotan_imbang_freq.transform(komentar2))
target_names = list(set(y_true))
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     non spam       0.99      0.93      0.96       726
#         spam       0.94      0.99      0.96       725
#
#     accuracy                           0.96      1451
#    macro avg       0.97      0.96      0.96      1451
# weighted avg       0.97      0.96      0.96      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %% [markdown]
# ### 3. Bin  CNB

# %%
y_pred = cnb_bin.predict(pembobotan_imbang_bin.transform(komentar))
target_names = list(set(y_true))
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     non spam       0.90      0.91      0.90       726
#         spam       0.91      0.90      0.90       725
#
#     accuracy                           0.90      1451
#    macro avg       0.90      0.90      0.90      1451
# weighted avg       0.90      0.90      0.90      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %%
y_pred = cnb_bin.predict(pembobotan_imbang_bin.transform(komentar2))
target_names = list(set(y_true))
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     non spam       1.00      0.93      0.96       726
#         spam       0.93      1.00      0.96       725
#
#     accuracy                           0.96      1451
#    macro avg       0.96      0.96      0.96      1451
# weighted avg       0.96      0.96      0.96      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %% [markdown]
# # MNB

# %%
mnb_tfidf = joblib.load(path+"imbang/"+"mnb_tfidf.model")
mnb_tf = joblib.load(path+"imbang/"+"mnb_tf.model")
mnb_bin = joblib.load(path+"imbang/"+"mnb_bin.model")

# %% [markdown]
# ### 1. TFIDF MNB

# %%
y_pred = mnb_tfidf.predict(pembobotan_imbang_freq.transform(komentar))
target_names = list(set(y_true))
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         spam       0.88      0.91      0.89       509
#     non spam       0.93      0.91      0.92       725
#
#     accuracy                           0.91      1234
#    macro avg       0.91      0.91      0.91      1234
# weighted avg       0.91      0.91      0.91      1234

# %% [markdown]
# ### 2. TF  MNB

# %%
y_pred = mnb_tf.predict(pembobotan_imbang_freq.transform(komentar))
target_names = list(set(y_true))
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         spam       0.86      0.94      0.90       509
#     non spam       0.96      0.90      0.93       725
#
#     accuracy                           0.92      1234
#    macro avg       0.91      0.92      0.91      1234
# weighted avg       0.92      0.92      0.92      1234

# %% [markdown]
# ### 3. Bin MNB

# %%
y_pred = mnb_bin.predict(pembobotan_imbang_bin.transform(komentar))
target_names = list(set(y_true))
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         spam       0.86      0.94      0.90       509
#     non spam       0.96      0.90      0.93       725
#
#     accuracy                           0.91      1234
#    macro avg       0.91      0.92      0.91      1234
# weighted avg       0.92      0.91      0.92      1234

# %% [markdown]
# # Gaussian

# %%
gnb_tfidf = joblib.load(path+"imbang/"+"gnb_tfidf.model")
gnb_tf = joblib.load(path+"imbang/"+"gnb_tf.model")
gnb_bin = joblib.load(path+"imbang/"+"gnb_bin.model")

# %% [markdown]
# ### 1. TFIDF

# %%
y_pred = gnb_tfidf.predict(pembobotan_imbang_freq.transform(komentar).A)
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     non spam       0.77      0.82      0.79       726
#         spam       0.80      0.75      0.78       725
#
#     accuracy                           0.78      1451
#    macro avg       0.78      0.78      0.78      1451
# weighted avg       0.78      0.78      0.78      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %%
y_pred = gnb_tfidf.predict(pembobotan_imbang_freq.transform(komentar2).A)
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     non spam       0.99      0.81      0.89       726
#         spam       0.84      0.99      0.91       725
#
#     accuracy                           0.90      1451
#    macro avg       0.91      0.90      0.90      1451
# weighted avg       0.91      0.90      0.90      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %% [markdown]
# ### 2. TF

# %%
y_pred = gnb_tf.predict(pembobotan_imbang_freq.transform(komentar).A)
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     non spam       0.77      0.82      0.79       726
#         spam       0.80      0.75      0.78       725
#
#     accuracy                           0.78      1451
#    macro avg       0.78      0.78      0.78      1451
# weighted avg       0.78      0.78      0.78      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %%
y_pred = gnb_tf.predict(pembobotan_imbang_freq.transform(komentar2).A)
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     non spam       0.99      0.81      0.89       726
#         spam       0.84      0.99      0.91       725
#
#     accuracy                           0.90      1451
#    macro avg       0.91      0.90      0.90      1451
# weighted avg       0.91      0.90      0.90      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %% [markdown]
# ### 3. BIN

# %%
y_pred = gnb_bin.predict(pembobotan_imbang_bin.transform(komentar).A)
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     non spam       0.75      0.82      0.78       726
#         spam       0.80      0.73      0.76       725
#
#     accuracy                           0.77      1451
#    macro avg       0.77      0.77      0.77      1451
# weighted avg       0.77      0.77      0.77      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %%
y_pred = gnb_bin.predict(pembobotan_imbang_bin.transform(komentar2).A)
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     non spam       0.99      0.80      0.89       726
#         spam       0.83      0.99      0.91       725
#
#     accuracy                           0.90      1451
#    macro avg       0.91      0.90      0.90      1451
# weighted avg       0.91      0.90      0.90      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %% [markdown]
# # NBC

# %%
nbc_bin = joblib.load(path+"imbang/"+"nbc_bin.model")
nbc_bin.alpha = 1

# %%
print(nbc_bin.alpha)
y_pred = nbc_bin.predict(np.array(komentar))
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
del y_pred
# Out:
# 1
#               precision    recall  f1-score   support
#
#     non spam       0.87      0.60      0.71       726
#         spam       0.69      0.91      0.79       725
#
#     accuracy                           0.75      1451
#    macro avg       0.78      0.75      0.75      1451
# weighted avg       0.78      0.75      0.75      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %%
print(nbc_bin.alpha)
y_pred = nbc_bin.predict(np.array(komentar2))
print(classification_report(y_true, y_pred))
print(plot.plot_confusion_matrix(y_true,y_pred))
del y_pred
# Out:
# 1
#               precision    recall  f1-score   support
#
#     non spam       0.98      0.56      0.71       726
#         spam       0.69      0.99      0.81       725
#
#     accuracy                           0.77      1451
#    macro avg       0.84      0.77      0.76      1451
# weighted avg       0.84      0.77      0.76      1451
#
# AxesSubplot(0.0706597,0.255582;0.723472x0.651362)

# %%
# unique_labels([1,2,2,4],[1,2,12,1,1])
